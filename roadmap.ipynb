# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1.5;">
#
#
#
#
# بسم الله الرحمن الرحیم
#
# مسیری که پیش میرویم
#
#
# ما برای اینکه بتوانیم هوش مصنوعی دیگری درست کنیم
# رفتیم سراغ هوش مصنوعی فعلی
# مدل های بیوهوشی مصنوعی و مدلهای مغز کامپیوتر و مدلهای دیگر رابررسی کردیم
# که در همین فایل ها وجود دارد
#
# بعد ما میخواستیم پردازش این همه سنگین نباشد و به صورت که انسان هم میتواند انجام شود
# یعنی مثل کودکی که اموزش میبنید و یاد میگیرد باشد ولی خب بشود از ان بهتر استفاده کرد
#
# در حقیقت مشکلات هوش مصنوعی فعلی را نداشته باشد
# ضمن اینکه بتوانیم در ان پیش گام هم باشیم
#
# به همین دلیل به برداشت های قران به خوداگاه و به حرکت جوهری نگاه کردیم
#
# چون دقیقا ما نمیدانیم که چیست ان چیزی که ما با ان به اگاهی میرسیم عقل است یا فطرت یا خود مغز که یکسری حرکات و حافظه و تجریه ذهنی و غیره دارد
#
# به همین دلیل خواستیم ببینمی اگر با حرکت جوهری یک ماده ای تولید کنیم میشود مثل قابلیت مغز داشته باشد
#
# که البته میرود در بیوهوش
#
# بعد دیدیم اگر بتوانیم بفهمانیم و یک سیستمی طراحی کنیم که بتواند خارج از شبکه های عصبی بتواند مثلا دارای هسته ای باشد که در ان یک سری بدیهیات انسان باشد
#
# یعنی مثلا هسته دارای منطق ارسطوی باشد
#
# که البته جنگ تحمیلی ایران و اسراییل شد
# و کلا رشته افکار پاره به همین دلیلی خواستیم همه چیز را بنویسیم و خط فکری را درست کنیم
#
# البته فایل ها موجود است
#
# مدل چامسکی مدل زبان جهانی مدل یکپارچگی در خوداگاهی و فهم برای ایجاد
# مدل حرکت جوهری
# و منطق ارسطویی و بدیهیات
#
# اینها چیزهایی هست که سعی شده فکر شودو درنظر گرفته شود
#
# دوم تیرماه ۱۴۰۴ چند روز قبل از محرم
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1.5;">
#
# فکر جدید
#
#
# میشود به این موضوع هم فکر کرد که هوش مصنوعی بر اساس قران وروایات و فلسفه اسلامی ساخت
#
# نه به کارگیری این هوش مصنوعی
# بلکه ساخت با هسته ای که این موضوعات را بفهمد و بتواند به زبان روز و عقل منطقی و روانشناسی پاسخ بدهد
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1.5;">
#
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1.5;">
#
# #### **یه پیشنهاد ترکیبی**
# شاید بهترین راه این باشه که یه هسته‌ی اولیه از اصول عقلانی داشته باشیم (مثل همونایی که گفتی)، ولی یه مکانیزم یادگیری هم بهش اضافه کنیم. اینطوری سیستم می‌تونه از تجربه‌ها یاد بگیره و یه ساختار پویا بسازه که هم اصول رو داره و هم با دنیا سازگار می‌شه. این شبیه چیزیه که توی ساخت‌گرایی یا حتی هوش مصنوعی امروزی (مثل یادگیری بدون نظارت) می‌بینیم.
#
# ---
#
# ### **نظر من چیه؟**
# به نظرم ایده‌ت که منطق ارسطویی با اصول و سورها هسته‌ی اصلی سیستم باشه، خیلی خوبه و می‌تونه یه شروع محکم باشه. این منطق به سیستم کمک می‌کنه که منظم و منطقی فکر کنه و تناقضات رو پیدا کنه. ولی اگه بخوایم سیستمی بسازیم که با دنیای واقعی و مسائل پیچیده‌تر کنار بیاد، احتمالاً باید بعداً چیزای دیگه‌ای بهش اضافه کنیم، مثل:
# - **منطق فازی**: برای کار با مفاهیم مبهم و احتمالی.
# - **منطق توصیفی**: برای روابط پیچیده‌تر و سلسله‌مراتبی.
# - **یادگیری**: که سیستم بتونه خودش از داده‌ها یاد بگیره.
#
# ---
# </div>

# %% [markdown]
# <div style="direction: rtl; white-space: pre-wrap; line-height: 1.5;">
#
#
#
# خب بررسی ها نشون میده که مدل های :
#
#
# جمع‌بندی
# مدل‌های دیگر: علاوه بر BriSe AI، Ouroboros، و ReSOM، مدل‌هایی مانند OpenCog، OpenNARS، Cyc، سیستم‌های مبتنی بر قواعد، و Neuro-Symbolic AI وجود دارند که ممکن است با منطق ارسطویی مرتبط باشند.
# نزدیک‌ترین مدل‌ها به منطق ارسطویی: OpenCog و OpenNARS به دلیل استفاده از منطق ترمی و قیاس‌های ارسطویی، نزدیک‌ترین مدل‌ها هستند. سیستم‌های مبتنی بر قواعد و AI-Aristotle نیز به‌طور غیرمستقیم به این منطق نزدیک‌اند.
# اجرای هسته منطق ارسطویی: این ایده در OpenCog و OpenNARS به‌طور مستقیم اجرا شده است، و در سیستم‌های مبتنی بر قواعد و AI-Aristotle به‌طور غیرمستقیم دیده می‌شود. با این حال، پیاده‌سازی‌های مقیاس‌پذیر و گسترده هنوز محدود هستند و نیاز به ترکیب با روش‌های مدرن دارند.
#
#
#
# یعنی عملا اولی ها پلفترم هایی هستند که یکی توی حالا عمومی هم هسته جدا و هم حالت چت بات داره brise ai
#
# یکی حالت بازتابی خیلی قوی داره و ممکنه حتی کلپس کنه یعنی ourboros
#
#
# یکی هم مبتنی بر شبکه های عصبی هست
#
#
# الان این وسط برای اینکه ببینیم هسته ارسطویی وجود داره یا نه باید بریم سراغ opencog , opennars
#
# الان در این مرحله هستمیم سوم تیرم ۱۴۰۴
# </div>
